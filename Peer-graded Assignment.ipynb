# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **Pablo Alejandro Arreguez**
#
# Head of Finance

# %% [markdown]
# *I am interested in data science because i would like to improve the performance of my management*

# %% [markdown]
# ### The following code tests the sum 2+2

# %%
2+2
# Out:
# 4

# %% [markdown]
# <a href="https://ibm.com">IBM</a>
#
# * A
# * B
# * C
#
# 1. A
# 2. B
# 3. C
#
#
# | A | B |
# | ------ | ------ |
# | 1 | 2 |
